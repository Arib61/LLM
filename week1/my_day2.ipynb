# %%
import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = "llama3.2"

# %%
messages = [
    {"role": "user", "content": "Describe some of the business applications of Generative AI"}
]

# %%
payload = {
        "model": MODEL,
        "messages": messages,
        "stream": False
    }

# %%
response = requests.post(OLLAMA_API,json=payload,headers=HEADERS)
print(response.json()['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries. Some examples include:
#
# 1. **Content Generation**: Generative AI can create high-quality content such as articles, social media posts, product descriptions, and more. This can help businesses save time and resources while maintaining consistency in their content.
# 2. **Product Design and Development**: Generative AI can aid in designing new products, such as 3D models, logos, and packaging designs. It can also be used to generate prototypes and simulations for testing.
# 3. **Marketing Automation**: Generative AI can help automate marketing processes by creating personalized ads, email campaigns, and social media content based on customer data and preferences.
# 4. **Customer Service Chatbots**: Generative AI-powered chatbots can provide 24/7 customer support, answering common questions, and routing complex issues to human representatives.
# 5. **Data Analysis and Visualization**: Generative AI can be used to analyze large datasets and generate visualizations, such as charts, graphs, and maps, to help businesses make data-driven decisions.
# 6. **Image and Video Editing**: Generative AI can automate image and video editing tasks, such as resizing, cropping, and enhancing images, and even generating new images or videos based on a style or theme.
# 7. **Music and Audio Generation**: Generative AI can create original music compositions, sound effects, and even entire audio tracks for films, TV shows, and other media productions.
# 8. **Speech Synthesis**: Generative AI-powered speech synthesis can be used to generate high-quality voiceovers for videos, audiobooks, and more.
# 9. **Predictive Analytics**: Generative AI can be used to analyze historical data and make predictions about future trends, helping businesses anticipate and prepare for changes in the market.
# 10. **Supply Chain Optimization**: Generative AI can help optimize supply chain operations by predicting demand, identifying bottlenecks, and recommending efficient logistics routes.
#
# Some of the key industries that are expected to benefit from generative AI include:
#
# * Finance and Banking
# * Healthcare and Biotechnology
# * E-commerce and Retail
# * Media and Entertainment
# * Education and Research
#
# The benefits of generative AI for businesses include:
#
# * Increased productivity and efficiency
# * Improved decision-making through data-driven insights
# * Enhanced customer experience through personalized content and services
# * Reduced costs through automation and reduced labor needs
# * New revenue streams through creative content and products generated by AI.

# %%
import ollama

response = ollama.chat(model=MODEL, messages=messages)
print(response['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries, including:
#
# 1. **Content Creation**: Generative AI can generate high-quality content such as articles, social media posts, product descriptions, and more. This can help reduce content creation costs and improve content consistency.
# 2. **Visual Content Generation**: Generative AI can create visual content like images, videos, and 3D models, which can be used for advertising, marketing, and entertainment purposes.
# 3. **Marketing Automation**: Generative AI can automate tasks such as email marketing campaigns, lead generation, and customer segmentation, helping businesses to personalize their marketing efforts.
# 4. **Personalized Product Recommendations**: Generative AI can analyze customer behavior and preferences to generate personalized product recommendations, improving customer engagement and sales.
# 5. **Chatbots and Virtual Assistants**: Generative AI can power chatbots and virtual assistants, enabling businesses to provide 24/7 customer support and automate routine inquiries.
# 6. **Product Design and Development**: Generative AI can assist in the design and development of new products by generating prototypes, testing designs, and optimizing product performance.
# 7. **Supply Chain Optimization**: Generative AI can analyze supply chain data and generate insights on how to optimize inventory levels, reduce waste, and improve logistics.
# 8. **Risk Management**: Generative AI can analyze large datasets to identify potential risks and provide recommendations for mitigating them, helping businesses to stay ahead of regulatory requirements.
# 9. **Cybersecurity Threat Detection**: Generative AI can detect and respond to cybersecurity threats by analyzing network traffic, identifying patterns, and predicting potential attacks.
# 10. **Data Analysis and Insights**: Generative AI can analyze large datasets and generate insights on trends, patterns, and correlations, helping businesses to make data-driven decisions.
# 11. **Customer Experience Optimization**: Generative AI can analyze customer feedback and behavior to optimize the overall customer experience, improving satisfaction rates and loyalty.
# 12. **Language Translation**: Generative AI can translate languages in real-time, enabling businesses to communicate with customers and clients across different regions and cultures.
# 13. **Audio and Music Generation**: Generative AI can create original music, audio tracks, and sound effects, which can be used for entertainment, advertising, or branding purposes.
# 14. **Fashion and Design**: Generative AI can generate fashion designs, textures, patterns, and even entire clothing lines, reducing the time and cost associated with traditional design processes.
# 15. **Healthcare and Medical Research**: Generative AI can analyze medical data to identify patterns, predict patient outcomes, and generate insights on new treatments and therapies.
#
# These are just a few examples of the many business applications of Generative AI. As the technology continues to evolve, we can expect to see even more innovative uses across various industries.
